# %%
import sys
sys.path.append('../')

from dataset_data.constants.var_types import VAR_TYPES

import itertools

import pandas as pd

import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Set seed
tf.random.set_seed(42)

# %%
# Path of all datasets
data_path = "../dataset_data/data"
num_datasets = [f"{data_path}/NORM_BCW.csv", f"{data_path}/NORM_Ecoli.csv", f"{data_path}/NORM_Iris.csv", f"{data_path}/NORM_ISOLET.csv", f"{data_path}/NORM_SDD.csv", f"{data_path}/NORM_PBC.csv", f"{data_path}/NORM_CMSC.csv", f"{data_path}/NORM_MagicGT.csv", f"{data_path}/NORM_Wine.csv"]
cat_datasets = [f"{data_path}/OH_BalanceScale.csv", f"{data_path}/OH_CarEvaluation.csv", f"{data_path}/OH_HayesRoth.csv", f"{data_path}/OH_Chess.csv", f"{data_path}/OH_Lymphography.csv", f"{data_path}/OH_Nursery.csv", f"{data_path}/OH_SoybeanSmall.csv", f"{data_path}/OH_TicTacToe.csv"]
mix_datasets = [f"{data_path}/OH_NORM_DefaultOfCCC.csv", f"{data_path}OH_NORM_StudentPerf.csv", f"{data_path}/OH_NORM_Adult.csv", f"{data_path}/OH_NORM_InternetAdv.csv", f"{data_path}/OH_NORM_StatlogGC.csv"]

# %%
def data_splitter(dsname, df, classes):
    """ Splitter for binary class DataFrames into train, validation and test in
    the proportion 60 20 20, respectively. It explicitly enforces the same proportion
    for each class.

    Args:
        df (DataFrame): DataFrame to be splitted
        classes (list): The DataFrame classes
    Returns:
        (DataFrame, DataFrame, DataFrame, DataFrame, DataFrame,
            DataFrame): DataFrames with the Train_X, Validation_X, Test_X, Train_y, Validation_y, Test_y

    """

    # Assert the output classes are binary
    assert len(list(set(classes) - {0, 1})) == 0

    # Get categorical features for the dataset
    cat_feats = VAR_TYPES[dsname]['categorical']

    # Get the original dataset
    original_ds = pd.read_csv(f'{data_path}/{dsname}.csv')

    # Set search parameters
    train_has_all_cats = False
    random_seed_number = 42
    tries = 0

    # Search for a train set that has all categorical values if it's not binary
    while not train_has_all_cats:

        # Start considering all categories are inside the train set
        train_has_all_cats = True

        # Sets
        X_trains = []
        X_validations = []
        X_tests = []
        y_trains = []
        y_validations = []
        y_tests = []

        # Iteration for each class
        for c in classes:

            df_s = df[df['output'] == c]
            X_train, X_test_validation, y_train, y_test_validation = train_test_split(
                df_s.drop(columns=['output']), df_s['output'], test_size=0.4, random_state=random_seed_number)

            X_test, X_validation, y_test, y_validation = train_test_split(
                X_test_validation, y_test_validation, test_size=0.5, random_state=random_seed_number)

            X_trains.append(X_train)
            X_validations.append(X_validation)
            X_tests.append(X_test)
            y_trains.append(y_train)
            y_validations.append(y_validation)
            y_tests.append(y_test)

        # Verify if all categories, non-binary, are represented in the train set
        for cat in cat_feats:
            if len(original_ds[cat].unique()) > 2:
                if len(original_ds.loc[pd.concat(X_trains).index][cat].unique()) != len(original_ds[cat].unique()):
                    train_has_all_cats = False
                    tries += 1
                    
        # If the number of tries surpasses 100, rises an error
        if tries == 100:
            print(dsname)
            raise ValueError('Could not find a way to get all categorical features inside the train')

        random_seed_number += 1

    return pd.concat(X_trains), pd.concat(X_validations), pd.concat(X_tests), pd.concat(y_trains), pd.concat(
        y_validations), pd.concat(y_tests)

# %%
import itertools

import pandas as pd

import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


def generate_models(paths_datasets):
    """ Model generator for a dataset in a specific path. It creates and saves the model, the
    train, validation and test indexes, each model parameter for the gridsearch and the parameters
    for the best model chosen (based on validation AUC)
    
    Args:
        path_datasets (list): A list containing the paths for each dataset to be analyzed
    Returns:
        (None)
    
    """
    for path_dataset in paths_datasets:
        # Generate df
        df = pd.read_csv(path_dataset)
        
        # Define the majority class as 0 and the other classes as 1, binarization
        most_common_class = df['output'].value_counts().index[0]
        df['output'] = df['output'].apply(lambda x: 0 if x==most_common_class else 1)
        
        # Get the name of the dataset
        ds_name = path_dataset.split('.')[2].split('_')[-1]
        
        # Get the possible classes of DS
        classes = list(df['output'].unique())
        
        # Split DataFrame to train, validation and test
        X_train, X_validation, X_test, y_train, y_validation, y_test = data_splitter(ds_name, df, classes)
        
        # Make y multiclass (as we need a 2 class output)
        y_train = pd.concat([y_train, y_train.map({0:1, 1:0})], axis=1)
        y_validation = pd.concat([y_validation, y_validation.map({0:1, 1:0})], axis=1)
        y_test = pd.concat([y_test, y_test.map({0:1, 1:0})], axis=1)
        
        print('##########################################')
        print(f'Size train: {len(X_train)}, {len(y_train)} \n')
        print(f'Size validation: {len(X_validation)}, {len(y_validation)} \n')
        print(f'Size test: {len(X_test)}, {len(y_test)} \n')
        print('##########################################')

        # Save model train Data indexes
        pd.DataFrame(y_train.index).rename(columns={0: 'index'}).to_csv(f'../dataset_data/idxstrain/{ds_name}.csv', index=False)
        
        # Save model validation Data indexes
        pd.DataFrame(y_validation.index).rename(columns={0: 'index'}).to_csv(f'../dataset_data/idxsvalidation/{ds_name}.csv', index=False)

        # Save test Data indexes
        pd.DataFrame(y_test.index).rename(columns={0: 'index'}).to_csv(f'../dataset_data/idxstest/{ds_name}.csv', index=False)


        # GridSearch Parameters
        learning_rates = [0.01, 0.001, 0.0001]
        epoch_numbers = [50, 100, 500]
        nn_sizes = []
        for i in range(1, 6):
            nnsize = int((X_train.shape[1]*2+1)*i/5)
            if nnsize not in nn_sizes:
                nn_sizes.append(nnsize)
        parameters = [learning_rates, epoch_numbers, nn_sizes]
        comb_param = list(itertools.product(*parameters))

        # best scores placeholders
        best_model = []
        best_params = []
        best_auc = 0.0

        for params in comb_param:
            
            # Get parameters
            lr = params[0]
            epoch = params[1]
            nn_size = params[2]


            # Create model
            model = keras.Sequential(
                [layers.Dense(nn_size, activation="relu", name="layer1"),
                 layers.Dense(2, activation="softmax", name="outputLayer"),
                ])

            # Configure optimizer
            opt = tf.keras.optimizers.RMSprop(learning_rate=lr, name='RMSprop')

            # Compile
            model.compile(optimizer=opt, loss="categorical_crossentropy", metrics=["accuracy"])

            # Train
            model.fit(X_train, y_train, epochs=epoch, verbose=0)

            # Get Prediction for train and validation set
            y_train_pred = model.predict(X_train)
            y_validation_pred = model.predict(X_validation)
            y_test_pred = model.predict(X_test)


            #Get Accuracies
            train_acc = accuracy_score(np.apply_along_axis(np.argmax, 1, y_train), np.apply_along_axis(np.argmax, 1, y_train_pred))
            validation_acc = accuracy_score(np.apply_along_axis(np.argmax, 1, y_validation), np.apply_along_axis(np.argmax, 1, y_validation_pred))
            test_acc = accuracy_score(np.apply_along_axis(np.argmax, 1, y_test), np.apply_along_axis(np.argmax, 1, y_test_pred))

            print(f"\n\nModel for {ds_name}:\nTrain Accuracy:{train_acc}\nValidation Accuracy:{validation_acc}\nTest Accuracy: {test_acc}\nClass Balance={y_train.sum()/y_train.shape[0]}\n\n")


            # Calculate auc score for Train and Validation
            fpr_train, tpr_train, thresholds_train = roc_curve(y_train.iloc[:,1:], pd.DataFrame(y_train_pred)[1])
            fpr_validation, tpr_validation, threshold_validations = roc_curve(y_validation.iloc[:,1:], pd.DataFrame(y_validation_pred)[1])
            
            auc_m_train = auc(fpr_train, tpr_train)
            auc_m_validation = auc(fpr_validation, tpr_validation)
            
            # Report auc for the params
            with open('./all_params.txt', 'a') as f:
                f.write(f'{ds_name} {auc_m_validation} {params} \n')

            if auc_m_validation > best_auc:
                best_auc = auc_m_validation
                best_model = model
                best_params = params
                
            # Release GPU memory
            tf.keras.backend.clear_session()
            del model

        # Report the best params and auc score for the dataset and class
        with open('./best_params.txt', 'a') as f:
            f.write(f'{ds_name} {best_auc} {best_params} \n')

        # Save
        best_model.save("./models/"+ds_name+".h5")

# %%
# Create models for numerical datasets
generate_models(num_datasets)
# Create models for categorical datasets
generate_models(cat_datasets)
# Create models for mixed datasets
generate_models(mix_datasets)
# Out:
# ##########################################
# Size train: 118, 118
#
# Size validation: 41, 41
#
# Size test: 39, 39
#
# ##########################################
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8536585365853658
# Test Accuracy: 0.7948717948717948
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8292682926829268
# Test Accuracy: 0.7948717948717948
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.940677966101695
# Validation Accuracy:0.7073170731707317
# Test Accuracy: 0.6153846153846154
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.717948717948718
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8048780487804879
# Test Accuracy: 0.7948717948717948
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8292682926829268
# Test Accuracy: 0.717948717948718
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8048780487804879
# Test Accuracy: 0.717948717948718
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.9661016949152542
# Validation Accuracy:0.7317073170731707
# Test Accuracy: 0.6410256410256411
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8048780487804879
# Test Accuracy: 0.7948717948717948
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.7560975609756098
# Test Accuracy: 0.5897435897435898
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8048780487804879
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8048780487804879
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.847457627118644
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.9067796610169492
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.9152542372881356
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7948717948717948
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.940677966101695
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.940677966101695
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.8898305084745762
# Validation Accuracy:0.8048780487804879
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.9576271186440678
# Validation Accuracy:0.8048780487804879
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.9830508474576272
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.9745762711864406
# Validation Accuracy:0.8048780487804879
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.9915254237288136
# Validation Accuracy:0.8780487804878049
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8536585365853658
# Test Accuracy: 0.7948717948717948
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.8048780487804879
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:1.0
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.5847457627118644
# Validation Accuracy:0.7073170731707317
# Test Accuracy: 0.6666666666666666
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.7457627118644068
# Validation Accuracy:0.6341463414634146
# Test Accuracy: 0.5897435897435898
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.6440677966101694
# Validation Accuracy:0.5121951219512195
# Test Accuracy: 0.6410256410256411
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.6864406779661016
# Validation Accuracy:0.7073170731707317
# Test Accuracy: 0.6410256410256411
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.8305084745762712
# Validation Accuracy:0.7317073170731707
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.7372881355932204
# Validation Accuracy:0.6585365853658537
# Test Accuracy: 0.6666666666666666
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.788135593220339
# Validation Accuracy:0.7560975609756098
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.7542372881355932
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.7796610169491526
# Validation Accuracy:0.7317073170731707
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.8305084745762712
# Validation Accuracy:0.7804878048780488
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.847457627118644
# Validation Accuracy:0.8292682926829268
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.9067796610169492
# Validation Accuracy:0.8536585365853658
# Test Accuracy: 0.7692307692307693
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.8983050847457628
# Validation Accuracy:0.8292682926829268
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.923728813559322
# Validation Accuracy:0.8292682926829268
# Test Accuracy: 0.7435897435897436
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
#
#
# Model for BCW:
# Train Accuracy:0.9322033898305084
# Validation Accuracy:0.8292682926829268
# Test Accuracy: 0.717948717948718
# Class Balance=output    0.237288
# output    0.762712
# dtype: float64
#
#
# ##########################################
# Size train: 200, 200
#
# Size validation: 68, 68
#
# Size test: 68, 68
#
# ##########################################
#
#
# Model for Ecoli:
# Train Accuracy:0.975
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.98
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.98
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.975
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.985
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.98
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.985
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9558823529411765
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.985
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.985
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.985
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.98
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.995
# Validation Accuracy:0.9117647058823529
# Test Accuracy: 0.9411764705882353
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:1.0
# Validation Accuracy:0.9264705882352942
# Test Accuracy: 0.9558823529411765
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.99
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9558823529411765
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:1.0
# Validation Accuracy:0.9117647058823529
# Test Accuracy: 0.9411764705882353
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.89
# Validation Accuracy:0.9264705882352942
# Test Accuracy: 0.9264705882352942
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.935
# Validation Accuracy:0.9264705882352942
# Test Accuracy: 0.9264705882352942
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.95
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.95
# Validation Accuracy:0.9264705882352942
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.975
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.95
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.975
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9558823529411765
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.965
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9558823529411765
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.975
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9558823529411765
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.97
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.97
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.975
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.975
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.975
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.985
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.815
# Validation Accuracy:0.8676470588235294
# Test Accuracy: 0.8382352941176471
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.88
# Validation Accuracy:0.8823529411764706
# Test Accuracy: 0.9558823529411765
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.465
# Validation Accuracy:0.5
# Test Accuracy: 0.45588235294117646
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.725
# Validation Accuracy:0.7352941176470589
# Test Accuracy: 0.7794117647058824
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.525
# Validation Accuracy:0.5588235294117647
# Test Accuracy: 0.5441176470588235
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.89
# Validation Accuracy:0.8235294117647058
# Test Accuracy: 0.9117647058823529
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.565
# Validation Accuracy:0.6029411764705882
# Test Accuracy: 0.6176470588235294
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.555
# Validation Accuracy:0.5735294117647058
# Test Accuracy: 0.6029411764705882
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.795
# Validation Accuracy:0.8235294117647058
# Test Accuracy: 0.8382352941176471
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.925
# Validation Accuracy:0.9264705882352942
# Test Accuracy: 0.9411764705882353
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.85
# Validation Accuracy:0.8823529411764706
# Test Accuracy: 0.8970588235294118
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.975
# Validation Accuracy:0.9558823529411765
# Test Accuracy: 0.9558823529411765
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.965
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.965
# Validation Accuracy:0.9411764705882353
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
#
#
# Model for Ecoli:
# Train Accuracy:0.97
# Validation Accuracy:0.9705882352941176
# Test Accuracy: 0.9705882352941176
# Class Balance=output    0.575
# output    0.425
# dtype: float64
#
#
# ##########################################
# Size train: 90, 90
#
# Size validation: 30, 30
#
# Size test: 30, 30
#
# ##########################################
#
#
# Model for Iris:
# Train Accuracy:0.9555555555555556
# Validation Accuracy:0.9333333333333333
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9333333333333333
# Test Accuracy: 0.9666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9333333333333333
# Test Accuracy: 0.9666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9333333333333333
# Test Accuracy: 0.9666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9333333333333333
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9333333333333333
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.5888888888888889
# Validation Accuracy:0.6333333333333333
# Test Accuracy: 0.6333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.6666666666666666
# Validation Accuracy:0.6666666666666666
# Test Accuracy: 0.6666666666666666
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.9222222222222223
# Validation Accuracy:0.9333333333333333
# Test Accuracy: 0.8666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.7444444444444445
# Validation Accuracy:0.7
# Test Accuracy: 0.7666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.8777777777777778
# Validation Accuracy:0.8333333333333334
# Test Accuracy: 0.8666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.8888888888888888
# Validation Accuracy:0.9666666666666667
# Test Accuracy: 0.8
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.9222222222222223
# Validation Accuracy:0.8333333333333334
# Test Accuracy: 0.9
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.8444444444444444
# Validation Accuracy:0.8333333333333334
# Test Accuracy: 0.9
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.9111111111111111
# Validation Accuracy:0.8666666666666667
# Test Accuracy: 0.8333333333333334
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.9666666666666667
# Validation Accuracy:0.9
# Test Accuracy: 0.9
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9333333333333333
# Test Accuracy: 0.9666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.9777777777777777
# Validation Accuracy:0.9
# Test Accuracy: 0.9666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:1.0
# Validation Accuracy:0.9
# Test Accuracy: 0.9
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.6666666666666666
# Validation Accuracy:0.6666666666666666
# Test Accuracy: 0.6666666666666666
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.28888888888888886
# Validation Accuracy:0.16666666666666666
# Test Accuracy: 0.3333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.8
# Validation Accuracy:0.8666666666666667
# Test Accuracy: 0.7333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.5555555555555556
# Validation Accuracy:0.43333333333333335
# Test Accuracy: 0.6666666666666666
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.7111111111111111
# Validation Accuracy:0.5
# Test Accuracy: 0.7333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.6444444444444445
# Validation Accuracy:0.7333333333333333
# Test Accuracy: 0.7666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.26666666666666666
# Validation Accuracy:0.3
# Test Accuracy: 0.13333333333333333
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.7
# Validation Accuracy:0.7666666666666667
# Test Accuracy: 0.8333333333333334
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.35555555555555557
# Validation Accuracy:0.5666666666666667
# Test Accuracy: 0.23333333333333334
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.4666666666666667
# Validation Accuracy:0.3
# Test Accuracy: 0.36666666666666664
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.8111111111111111
# Validation Accuracy:0.7
# Test Accuracy: 0.7666666666666667
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.8111111111111111
# Validation Accuracy:0.8333333333333334
# Test Accuracy: 0.9
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.6444444444444445
# Validation Accuracy:0.5333333333333333
# Test Accuracy: 0.5
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.9222222222222223
# Validation Accuracy:0.8666666666666667
# Test Accuracy: 0.9
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
#
#
# Model for Iris:
# Train Accuracy:0.8888888888888888
# Validation Accuracy:0.8
# Test Accuracy: 0.9
# Class Balance=output    0.666667
# output    0.333333
# dtype: float64
#
#
# ##########################################
# Size train: 4678, 4678
#
# Size validation: 1560, 1560
#
# Size test: 1559, 1559
#
# ##########################################
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9974358974358974
# Test Accuracy: 0.9955099422706863
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9974342527261065
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9980769230769231
# Test Accuracy: 0.9987171263630532
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9967948717948718
# Test Accuracy: 0.9980756895445798
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9967928159076331
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9974358974358974
# Test Accuracy: 0.9974342527261065
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9974358974358974
# Test Accuracy: 0.9974342527261065
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9974358974358974
# Test Accuracy: 0.9974342527261065
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9987171263630532
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9967928159076331
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9980769230769231
# Test Accuracy: 0.9980756895445798
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9967948717948718
# Test Accuracy: 0.9987171263630532
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9980769230769231
# Test Accuracy: 0.9980756895445798
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9974358974358974
# Test Accuracy: 0.9980756895445798
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9987171263630532
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9987171263630532
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9980756895445798
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9987171263630532
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9980756895445798
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9987171263630532
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:1.0
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9980756895445798
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9987171263630532
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9974342527261065
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9980756895445798
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9987171263630532
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9987179487179487
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
#
#
# Model for ISOLET:
# Train Accuracy:1.0
# Validation Accuracy:0.9993589743589744
# Test Accuracy: 0.9993585631815266
# Class Balance=output    0.961522
# output    0.038478
# dtype: float64
#
#
# ##########################################
# Size train: 35105, 35105
#
# Size validation: 11702, 11702
#
# Size test: 11702, 11702
#
# ##########################################
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9998290890446078
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9997436335669116
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9998290890446078
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9998290890446078
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9998290890446078
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9998290890446078
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9999145445223039
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9999145445223039
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9998290890446078
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9997436335669116
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9997436335669116
# Test Accuracy: 0.9997436335669116
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999715140293406
# Validation Accuracy:0.9997436335669116
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9997436335669116
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9997436335669116
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9997436335669116
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9997436335669116
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9997436335669116
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9999145445223039
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9997436335669116
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9997436335669116
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999145420880217
# Validation Accuracy:0.9997436335669116
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999145420880217
# Validation Accuracy:0.9997436335669116
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999145420880217
# Validation Accuracy:0.9997436335669116
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999145420880217
# Validation Accuracy:0.9997436335669116
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999145420880217
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999145420880217
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999145420880217
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999430280586811
# Validation Accuracy:0.9997436335669116
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999145420880217
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:0.9999430280586811
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
#
#
# Model for SDD:
# Train Accuracy:1.0
# Validation Accuracy:0.9998290890446078
# Test Accuracy: 0.9996581780892155
# Class Balance=output    0.909101
# output    0.090899
# dtype: float64
#
#
# ##########################################
# Size train: 3283, 3283
#
# Size validation: 1095, 1095
#
# Size test: 1095, 1095
#
# ##########################################
#
#
# Model for PBC:
# Train Accuracy:0.9689308559244594
# Validation Accuracy:0.960730593607306
# Test Accuracy: 0.965296803652968
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9643618641486446
# Validation Accuracy:0.9598173515981735
# Test Accuracy: 0.9643835616438357
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9719768504416693
# Validation Accuracy:0.9643835616438357
# Test Accuracy: 0.9625570776255707
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9728906487968322
# Validation Accuracy:0.971689497716895
# Test Accuracy: 0.9689497716894977
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9710630520865062
# Validation Accuracy:0.9707762557077626
# Test Accuracy: 0.9643835616438357
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9731952482485532
# Validation Accuracy:0.9634703196347032
# Test Accuracy: 0.9707762557077626
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9762412427657631
# Validation Accuracy:0.9707762557077626
# Test Accuracy: 0.9707762557077626
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9795918367346939
# Validation Accuracy:0.9735159817351599
# Test Accuracy: 0.9762557077625571
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9823332318001827
# Validation Accuracy:0.9680365296803652
# Test Accuracy: 0.9753424657534246
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9805056350898569
# Validation Accuracy:0.9689497716894977
# Test Accuracy: 0.9753424657534246
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.975022844958879
# Validation Accuracy:0.9671232876712329
# Test Accuracy: 0.9689497716894977
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.976850441669205
# Validation Accuracy:0.960730593607306
# Test Accuracy: 0.9726027397260274
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.977459640572647
# Validation Accuracy:0.9625570776255707
# Test Accuracy: 0.971689497716895
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9795918367346939
# Validation Accuracy:0.9616438356164384
# Test Accuracy: 0.9707762557077626
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9835516296070667
# Validation Accuracy:0.9707762557077626
# Test Accuracy: 0.9771689497716894
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9594882729211087
# Validation Accuracy:0.9552511415525115
# Test Accuracy: 0.9671232876712329
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9661894608589705
# Validation Accuracy:0.965296803652968
# Test Accuracy: 0.9643835616438357
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9692354553761803
# Validation Accuracy:0.965296803652968
# Test Accuracy: 0.9643835616438357
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9701492537313433
# Validation Accuracy:0.9662100456621004
# Test Accuracy: 0.9643835616438357
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9695400548279013
# Validation Accuracy:0.9689497716894977
# Test Accuracy: 0.9671232876712329
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9674078586658544
# Validation Accuracy:0.9680365296803652
# Test Accuracy: 0.9643835616438357
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9719768504416693
# Validation Accuracy:0.9698630136986301
# Test Accuracy: 0.9735159817351599
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9731952482485532
# Validation Accuracy:0.9726027397260274
# Test Accuracy: 0.971689497716895
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9713676515382272
# Validation Accuracy:0.9707762557077626
# Test Accuracy: 0.9698630136986301
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.977155041120926
# Validation Accuracy:0.971689497716895
# Test Accuracy: 0.9726027397260274
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9698446542796223
# Validation Accuracy:0.9698630136986301
# Test Accuracy: 0.9726027397260274
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.975632043862321
# Validation Accuracy:0.9671232876712329
# Test Accuracy: 0.971689497716895
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9795918367346939
# Validation Accuracy:0.9689497716894977
# Test Accuracy: 0.9753424657534246
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9829424307036247
# Validation Accuracy:0.9689497716894977
# Test Accuracy: 0.9735159817351599
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9798964361864149
# Validation Accuracy:0.9744292237442922
# Test Accuracy: 0.9726027397260274
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.8976545842217484
# Validation Accuracy:0.897716894977169
# Test Accuracy: 0.897716894977169
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9448674992385013
# Validation Accuracy:0.94337899543379
# Test Accuracy: 0.9515981735159817
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9436491014316174
# Validation Accuracy:0.947945205479452
# Test Accuracy: 0.947945205479452
# Class Balance=output    0.102345
# output    0.897655
# dtype: float64
#
#
#
#
# Model for PBC:
# Train Accuracy:0.9494364910143162
# Validation Accuracy:0.9488584474885845
# ...
#
#
# ##########################################
# Size train: 1414, 1414
#
# Size validation: 473, 473
#
# Size test: 472, 472
#
# ##########################################
#
#
# Model for InternetAdv:
# Train Accuracy:0.9985855728429985
# Validation Accuracy:0.9577167019027484
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.959830866807611
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.9703389830508474
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9985855728429985
# Validation Accuracy:0.9577167019027484
# Test Accuracy: 0.9682203389830508
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9985855728429985
# Validation Accuracy:0.9577167019027484
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9556025369978859
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9556025369978859
# Test Accuracy: 0.9703389830508474
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9556025369978859
# Test Accuracy: 0.9703389830508474
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9985855728429985
# Validation Accuracy:0.9577167019027484
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.959830866807611
# Test Accuracy: 0.9745762711864406
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9471458773784355
# Test Accuracy: 0.9597457627118644
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9471458773784355
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9492600422832981
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9492600422832981
# Test Accuracy: 0.9766949152542372
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9534883720930233
# Test Accuracy: 0.9703389830508474
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9985855728429985
# Validation Accuracy:0.959830866807611
# Test Accuracy: 0.9639830508474576
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9985855728429985
# Validation Accuracy:0.959830866807611
# Test Accuracy: 0.9639830508474576
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9985855728429985
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.9639830508474576
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9978783592644979
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9978783592644979
# Validation Accuracy:0.9640591966173362
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.959830866807611
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.959830866807611
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9577167019027484
# Test Accuracy: 0.9597457627118644
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9577167019027484
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.959830866807611
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9556025369978859
# Test Accuracy: 0.9682203389830508
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9513742071881607
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9534883720930233
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:1.0
# Validation Accuracy:0.9492600422832981
# Test Accuracy: 0.9639830508474576
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9929278642149929
# Validation Accuracy:0.9725158562367865
# Test Accuracy: 0.9682203389830508
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9936350777934936
# Validation Accuracy:0.9704016913319239
# Test Accuracy: 0.9682203389830508
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.995049504950495
# Validation Accuracy:0.9682875264270613
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9957567185289957
# Validation Accuracy:0.9682875264270613
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9957567185289957
# Validation Accuracy:0.9661733615221987
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9957567185289957
# Validation Accuracy:0.9661733615221987
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9978783592644979
# Validation Accuracy:0.9640591966173362
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9978783592644979
# Validation Accuracy:0.9640591966173362
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9978783592644979
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9985855728429985
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.9661016949152542
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.9639830508474576
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.9597457627118644
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
#
#
# Model for InternetAdv:
# Train Accuracy:0.9992927864214993
# Validation Accuracy:0.9619450317124736
# Test Accuracy: 0.961864406779661
# Class Balance=output    0.161245
# output    0.838755
# dtype: float64
#
#
# ##########################################
# Size train: 600, 600
#
# Size validation: 200, 200
#
# Size test: 200, 200
#
# ##########################################
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.71
# Test Accuracy: 0.695
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.725
# Test Accuracy: 0.725
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.725
# Test Accuracy: 0.67
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.765
# Test Accuracy: 0.705
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.705
# Test Accuracy: 0.69
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.69
# Test Accuracy: 0.675
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.745
# Test Accuracy: 0.675
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.715
# Test Accuracy: 0.695
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.71
# Test Accuracy: 0.68
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.74
# Test Accuracy: 0.685
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.68
# Test Accuracy: 0.655
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.68
# Test Accuracy: 0.695
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.71
# Test Accuracy: 0.725
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.73
# Test Accuracy: 0.7
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.705
# Test Accuracy: 0.695
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.875
# Validation Accuracy:0.765
# Test Accuracy: 0.71
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.9383333333333334
# Validation Accuracy:0.76
# Test Accuracy: 0.735
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.9666666666666667
# Validation Accuracy:0.74
# Test Accuracy: 0.69
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.9883333333333333
# Validation Accuracy:0.74
# Test Accuracy: 0.705
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.995
# Validation Accuracy:0.765
# Test Accuracy: 0.7
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.9416666666666667
# Validation Accuracy:0.73
# Test Accuracy: 0.725
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.9983333333333333
# Validation Accuracy:0.75
# Test Accuracy: 0.68
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.745
# Test Accuracy: 0.685
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.73
# Test Accuracy: 0.695
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.705
# Test Accuracy: 0.705
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.72
# Test Accuracy: 0.665
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.73
# Test Accuracy: 0.685
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.735
# Test Accuracy: 0.7
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.73
# Test Accuracy: 0.725
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:1.0
# Validation Accuracy:0.74
# Test Accuracy: 0.72
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.7616666666666667
# Validation Accuracy:0.76
# Test Accuracy: 0.73
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.78
# Validation Accuracy:0.77
# Test Accuracy: 0.785
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.79
# Validation Accuracy:0.75
# Test Accuracy: 0.79
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.81
# Validation Accuracy:0.765
# Test Accuracy: 0.75
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.8033333333333333
# Validation Accuracy:0.77
# Test Accuracy: 0.78
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.7916666666666666
# Validation Accuracy:0.735
# Test Accuracy: 0.79
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.815
# Validation Accuracy:0.76
# Test Accuracy: 0.765
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.8233333333333334
# Validation Accuracy:0.78
# Test Accuracy: 0.775
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.8316666666666667
# Validation Accuracy:0.74
# Test Accuracy: 0.75
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.8466666666666667
# Validation Accuracy:0.75
# Test Accuracy: 0.765
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.8933333333333333
# Validation Accuracy:0.75
# Test Accuracy: 0.725
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.96
# Validation Accuracy:0.78
# Test Accuracy: 0.715
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.985
# Validation Accuracy:0.76
# Test Accuracy: 0.705
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.9966666666666667
# Validation Accuracy:0.745
# Test Accuracy: 0.695
# Class Balance=output    0.3
# output    0.7
# dtype: float64
#
#
#
#
# Model for StatlogGC:
# Train Accuracy:0.995
# Validation Accuracy:0.76
# Test Accuracy: 0.705
# Class Balance=output    0.3
# output    0.7
# dtype: float64
